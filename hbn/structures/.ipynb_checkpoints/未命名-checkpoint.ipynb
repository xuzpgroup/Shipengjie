# %%
from ase.io import read, write
from ase.build import make_supercell,sort
import numpy as np
from ase.neighborlist import natural_cutoffs,NeighborList
import matplotlib.pyplot as plt

# %%
atom = read('99.xyz')

# %%
atom
# Out:
# Atoms(symbols='B486N486', pbc=True, cell=[39.10314667281021, 67.7286335700058, 100.0], forces=..., calculator=SinglePointCalculator(...))

# %%
new_atom = make_supercell(atom,[[51,0,0],[0,8,0],[0,0,1]])

# %%
new_atom
# Out:
# Atoms(symbols='B198288N198288', pbc=True, cell=[1994.2604803133208, 541.8290685600464, 100.0], forces=...)

# %%
write('99_large.xyz',new_atom)
